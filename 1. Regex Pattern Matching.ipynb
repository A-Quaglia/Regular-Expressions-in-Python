# %% [markdown]
# # Regular Expressions for Pattern Matching
# ## Regex metacharacters
# - `\d` - digit
# - `\s` - whitespace
# - `\w` - word
# - `{3,10}` - leftmost character should appear between 3 and 10 times
# - `\D` - non-digit
# - `\W` - non-word
#
# ## Regex Quantifiers
# - `{8}` - repeated 8 times
# - `{2,8}` - repeated to 2 to 8 times
# - `{3,}` - repeated at least 3 times
# - `+` - character appears one or more times
# - `*`  - character appears zero or more times
# - `?` - character appears zero or once
#
# ## Regex Special Chars
# - `^` - start of string
# - `$` - end of string
# - `.` - any char
# - `\` - scape
# - `|` - or
# - `[]` - set of chars
# - `^` - not
#
# ## Greedy vs. non-greedy matching
# Greedy: match as many characters as possible
# Lazy: match as few characters as needed
#
# ## Alternation and non-capturing groups
# - ADD: `?:` `(?:regex)`
#
# ## Backreferences
# - `?P<name>regex` - name groups
# - `\1` `\2` refers back to last n or more regex group
# - `?p=group_name` refers back to group name
# - `\g<name>` - refers back to group for replacement reference
#
# ## Lookaround
# ### look-ahead
# - `?=regex` - positive
# - `?!run` - negative
# ### look-behind
# - `?<=regex` - positive
# - `?<!regex` - negative

# %% [markdown]
# # Tweets analyses

# %% [markdown]
# 1. Identify robot mentions

# %%
import pandas as pd
import re

df = pd.read_csv('datasets\short_tweets.csv')
print(df.shape)
df.head(3)
# Out:
# (19948, 6)
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\augus\AppData\Local\Temp\ipykernel_19360\1938022835.py:4: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv('datasets\short_tweets.csv')
#    target          id                          date      flag            user  \
# 0       0  1467821085  Mon Apr 06 22:22:26 PDT 2009  NO_QUERY  crzy_cdn_bulas
# 1       0  1467821338  Mon Apr 06 22:22:30 PDT 2009  NO_QUERY     justnetgirl
# 2       0  1467821455  Mon Apr 06 22:22:32 PDT 2009  NO_QUERY      CiaraRenee
#
#                                                 text
# 0  our duck and chicken are taking wayyy too long...
# 1  Put vacation photos online (They were so cute)...
# 2                                      I need a hug

# %%
regex = r"@robot\d\W"

print("mentions:")
print([tweet for tweet in df['text'].str.findall(regex) if len(tweet)>0])
print("tweets:")
display(df[df['text'].str.match(regex)== True])
# Out:
# mentions:
# [['@robot9!', '@robot4&', '@robot9$', '@robot7%']]
# tweets:
#      target          id                          date      flag        user  \
# 105       0  1467852067  Mon Apr 06 22:30:34 PDT 2009  NO_QUERY  kirstenj0y
#
#                                                   text
# 105  @robot9! @robot4& I have a good feeling that t...

# %% [markdown]
# 2.  Find user mentions

# %%
regex = r"@\w+"

print("mentions:")
print([tweet for tweet in df['text'].str.findall(regex) if len(tweet)>0])
print("tweets:")
display(df[df['text'].str.match(regex)== True])
# Out:
# mentions:
'], ['@celycarmo'], ['@OfficialRandL'], ['@KishoreK'], ['@RandomlyNat'], ['@SupaMagg'], ['@treesahquiche'], ['@jennifermf'], ['@mamasvan'], ['@maxime68', '@megelder'], ['@jillianfish'], ['@anistorm'], ['@sleep_til_noon'], ['@B_Barnett'], ['@nicolerichie'], ['@akianz'], ['@EazyDoesIt87'], ['@Sofii_Noel'], ['@KevChoice'], ['@frago'], ['@NileLegania'], ['@ddlovato', '@David_Henrie'], ['@corrosivecandy'], ['@AmaNorris'], ['@nomadicmatt'], ['@ShareThis'], ['@Appomattox_News'], ['@jeffreecuntstar'], ['@lauredhel'], ['@brian_armstrong'], ['@margaretcho'], ['@lolitariot'], ['@alejandralei'], ['@RumLover'], ['@kaeeeep'], ['@Brodhe'], ['@jyesmith'], ['@Anistorm'], ['@cleders'], ['@shandasaurus'], ['@Houndour'], ['@stuiy'], ['@pratama'], ['@Miss_Sil'], ['@JonathanRKnight'], ['@JinxCat'], ['@emmaketurah'], ['@Snick_the_Dog'], ['@HumanOpium'], ['@ilovepie'], ['@JonathanRKnight'], ['@KelleyRowe'], ['@sasii'], ['@hert'], ['@MaryBethune'], ['@ginayates'], ['@ewarden'], ['@miamiiboii'], ['@arlenecd'], ['@phlaimeaux'], ['@emilyruppe'], ['@nicolerichie'], ['@chordsy'], ['@lovebscott'], ['@heidimontag'], ['@JonathanRKnight'], ['@daniela_95616'], ['@ddlovato'], ['@ballinbitch'], ['@paul_e_wog'], ['@carlyw66'], ['@sloanb'], ['@nachojohnny'], ['@heidimontag'], ['@JessDubb'], ['@LizChavez'], ['@daniela_95616'], ['@heidimontag'], ['@nick_carter'], ['@blueKnight39'], ['@anitaLopez98', '@MyredHat31'], ['@YourBestCompany', '@foxRadio'], ['@Born_4_Broadway'], ['@b ...
# tweets:
#        target          id                          date      flag  \
# 3           0  1467821715  Mon Apr 06 22:22:37 PDT 2009  NO_QUERY
# 4           0  1467822384  Mon Apr 06 22:22:47 PDT 2009  NO_QUERY
# 8           0  1467822687  Mon Apr 06 22:22:52 PDT 2009  NO_QUERY
# 13          0  1467824199  Mon Apr 06 22:23:15 PDT 2009  NO_QUERY
# 16          0  1467825003  Mon Apr 06 22:23:28 PDT 2009  NO_QUERY
# ...       ...         ...                           ...       ...
# 19930       0  1556973243  Sun Apr 19 01:18:32 PDT 2009  NO_QUERY
# 19937       0  1556974294  Sun Apr 19 01:18:54 PDT 2009  NO_QUERY
# 19938       0  1556974470  Sun Apr 19 01:18:58 PDT 2009  NO_QUERY
# 19939       0  1556974516  Sun Apr 19 01:18:59 PDT 2009  NO_QUERY
# 19940       0  1556974750  Sun Apr 19 01:19:03 PDT 2009  NO_QUERY
#
#                   user                                               text
# 3               deelau  @andywana Not sure what they are, only that th...
# 4          Lindsey0920             @oanhLove I hate when that happens...
# 8        xVivaLaJuicyx  @BatManYNG I miss my ps3, it's out of commissi...
# 13           adri_mane  @Starrbby too bad I won't be around I lost my ...
# 16       leslierosales            @katortiz  Not forever... See you soon!
# ...                ...                                                ...
# 19930  RachaelPhillips  @CaiGriffiths  poor thing. When they're out ru...
# 19937   CaptiveCulture  @BindMe but that's true you have to block late...
# 19938    paperclipface  @TyPie I think I am going to seek out more thi...
# 19939       SirCrumpet                  @Rogerthatv2 Not looking hopeful
# 19940          dswints  @2Hood4Hollywood I know  I'm sorry...I got cau...
#
# [6840 rows x 6 columns]

# %% [markdown]
# 3. find links

# %%
regex = r"https?.+?\s"

print("mentions:")
print([tweet for tweet in df['text'].str.findall(regex) if len(tweet)>0])
print("tweets:")
display(df[df['text'].str.match(regex)== True])
# Out:
# mentions:
# [['http://twitpic.com/2y2wr '], ['http://twitpic.com/2y2yi '], ['https://www.mycomicshop.com/search?TID=395031 '], ['http://twitpic.com/2y34e '], ['http://tinyurl.com/dc2htx '], ['http://twitpic.com/2y36e '], ['http://is.gd/r8Zf, ', 'http://is.gd/r8Zy, ', 'http://is.gd/r8ZG '], ['http://twitpic.com/2y3cf '], ['https://radio.foxnews.com '], ['http://twitpic.com/2y1pe '], ['http://sp2.ro/5b7bdb '], ['http://www.krispykreme.com.my/ '], ['http://tinyurl.com/dmukpr), '], ['http://www.rightpundits.com/?p=3669 '], ['http://community.livejournal.com/ohnotheydidnt/33907252.html '], ['http://twitpic.com/2y4vn '], ['http://bit.ly/kHBN '], ['http://is.gd/r9vr '], ['http://tinyurl.com/djjc46 '], ['http://twitpic.com/2y5s9 '], ['http://twitpic.com/2y65i '], ['http://twitpic.com/2xszg '], ['http://tinyurl.com/djh4pr '], ['http://bit.ly/4dVYg3 '], ['http://twitpic.com/2y606 '], ['http://twitpic.com/2y6z6 '], ['http://twurl.nl/iyar6d '], ['http://tinyurl.com/c5mja5 '], ['http://twitpic.com/2y7bg '], ['http://tinyurl.com/holdisgiantcherry '], ['http://twitpic.com/2ved8 '], ['http://tr.im/imOv '], ['http://twitter.com/freddybust/status/1463411617 '], ['http://twitpic.com/2y867 '], ['http://twitpic.com/2y887 '], ['http://www.smartestgames.com/gotdhistory.php?id=141 '], ['http://www.smartestgames.com/gotd.php '], ['http://twitpic.com/2y8lt '], ['http://twt.fm/33009 '], ['http://ow.ly/2fRj '], ['http://tinyurl.com/3xzzcb '], ['http://is.gd/raX6 ', 'http://is.gd/raWM. '], ['http://is.gd/raZl '], ['http://twitpic.com/2y9xm '], ['http://twitpic.com/2ya1c '], ['http://www.amazon.com/I-Am/dp/B001CQ6578 '], ['http://tr.im/in2l '], ['http://www.smartestgames.com/gotd.php '], ['http://news.aol.com/?feature=416950 '], ['http://www.abc.net.au/news/stories/2009/04/02/2533045.htm?section=entertainment '], ['http://tinyurl.com/3p7653 '], ['http://twitpic.com/2yb45 '], ['http://bit.ly/rKfaO '], ['http://twitpic.com/2yafi '],
PDT 2009  NO_QUERY
# ...       ...         ...                           ...       ...
# 19221       0  1556810633  Sun Apr 19 00:27:33 PDT 2009  NO_QUERY
# 19308       0  1556832860  Sun Apr 19 00:34:07 PDT 2009  NO_QUERY
# 19506       0  1556879397  Sun Apr 19 00:48:19 PDT 2009  NO_QUERY
# 19596       0  1556903436  Sun Apr 19 00:55:57 PDT 2009  NO_QUERY
# 19817       0  1556950777  Sun Apr 19 01:10:57 PDT 2009  NO_QUERY
#
#                user                                               text
# 258        sarawang  http://twitpic.com/2y2wr - according to my bro...
# 303         Mowgli3      http://twitpic.com/2y2yi - I love you, Buck.
# 382        cinnayum  http://twitpic.com/2y34e - I wanna wear my Doc...
# 422        utehbaik  http://twitpic.com/2y36e - cant see the flower...
# 465        tjslater  http://is.gd/r8Zf,  http://is.gd/r8Zy, and  ht...
# ...             ...                                                ...
# 19221     missC1977  http://twitpic.com/3l2zm - another rainy day i...
# 19308    itscatbaby  http://twitpic.com/3l37i - @dangerradio i have...
# 19506    marykate_L         http://twitpic.com/3l3m2 - My Bruised Arm
# 19596  ReallyCookin  http://twitpic.com/3l3uq - for the record... t...
# 19817    tevroliana  http://twitpic.com/3l467 - the Uzz  brothers d...
#
# [74 rows x 6 columns]

# %%
regex = r"\S+\.com\S+"

print("mentions:")
print([tweet for tweet in df['text'].str.findall(regex) if len(tweet)>0])
print("tweets:")
display(df[df['text'].str.match(regex)== True])
# Out:
# mentions:
# [['http://twitpic.com/2y2es'], ['http://apps.facebook.com/dogbook/profile/view/5248435'], ['http://apps.facebook.com/dogbook/profile/view/6176014'], ['http://twitpic.com/2y2wr'], ['http://tinyurl.com/cw2l9t'], ['http://tinyurl.com/ceprvs'], ['http://twitpic.com/2y2yi'], ['https://www.mycomicshop.com/search?TID=395031'], ['http://tinyurl.com/cec5ka'], ['http://twitpic.com/2y34e'], ['http://tinyurl.com/dc2htx'], ['http://twitpic.com/2y36e'], ['http://tinyurl.com/c4ooho'], ['http://twitpic.com/2y3cf'], ['http://tinyurl.com/c8bvqh'], ['http://tinyurl.com/cxe8w7'], ['http://fanclub.backstreetboys.com/chat.php'], ['http://twitpic.com/2y1pe'], ['http://twitpic.com/2y3jp'], ['http://twitpic.com/2y3ty'], ['http://twitpic.com/2y3y0'], ['http://plurk.com/p/mzxbg'], ['http://plurk.com/p/mzxcs'], ['http://www.tv.com/story/13720.html?ref_story_id=13720&amp;ref_type=1101&amp;ref_name=story'], ['http://plurk.com/p/mzygb'], ['http://tinyurl.com/cexkqy'], ['http://apps.facebook.com/dogbook/profile/view/4744827'], ['http://twitpic.com/2y4bh'], ['http://tinyurl.com/64skpp'], ['http://tinyurl.com/64skpp'], ['http://twitpic.com/2y4j5'], ['http://www.krispykreme.com.my/'], ['(http://tinyurl.com/dmukpr),'], ['http://www.rightpundits.com/?p=3669'], ['http://www.youtube.com/watch?v=EUJSME0TORw'], ['http://community.livejournal.com/ohnotheydidnt/33907252.html'], ['http://twitpic.com/2y4vn'], ['http://tinyurl.com/dhq7xv'], ['http://www.yout
# tweets:
#        target          id                          date      flag  \
# 258         0  1467892720  Mon Apr 06 22:41:20 PDT 2009  NO_QUERY
# 303         0  1467900244  Mon Apr 06 22:43:26 PDT 2009  NO_QUERY
# 382         0  1467922983  Mon Apr 06 22:49:51 PDT 2009  NO_QUERY
# 422         0  1467931396  Mon Apr 06 22:52:11 PDT 2009  NO_QUERY
# 512         0  1467951931  Mon Apr 06 22:58:05 PDT 2009  NO_QUERY
# ...       ...         ...                           ...       ...
# 19221       0  1556810633  Sun Apr 19 00:27:33 PDT 2009  NO_QUERY
# 19308       0  1556832860  Sun Apr 19 00:34:07 PDT 2009  NO_QUERY
# 19506       0  1556879397  Sun Apr 19 00:48:19 PDT 2009  NO_QUERY
# 19596       0  1556903436  Sun Apr 19 00:55:57 PDT 2009  NO_QUERY
# 19817       0  1556950777  Sun Apr 19 01:10:57 PDT 2009  NO_QUERY
#
#                user                                               text
# 258        sarawang  http://twitpic.com/2y2wr - according to my bro...
# 303         Mowgli3      http://twitpic.com/2y2yi - I love you, Buck.
# 382        cinnayum  http://twitpic.com/2y34e - I wanna wear my Doc...
# 422        utehbaik  http://twitpic.com/2y36e - cant see the flower...
# 512       mitrepeak  http://twitpic.com/2y3cf - Filled with curry  ...
# ...             ...                                                ...
# 19221     missC1977  http://twitpic.com/3l2zm - another rainy day i...
# 19308    itscatbaby  http://twitpic.com/3l37i - @dangerradio i have...
# 19506    marykate_L         http://twitpic.com/3l3m2 - My Bruised Arm
# 19596  ReallyCookin  http://twitpic.com/3l3uq - for the record... t...
# 19817    tevroliana  http://twitpic.com/3l467 - the Uzz  brothers d...
#
# [70 rows x 6 columns]

# %% [markdown]
# 4. removing hashtags

# %%
regex = r"#\S+"

df['text'].str.replace(regex, '')
print("tweets:")
display(df['text'][df['text'].str.match(regex)== True].head())
display(df['text'].str.replace(regex, '', regex=True)[df['text'].str.match(regex)== True].head())
# Out:
# tweets:
# 348     #3 woke up and was having an accident - &quot;...
# 979     #travian Total cost of the atk for the aggress...
# 2030    #mhbigcatch 8oz Golem  But finally got a Wight...
# 2404          #php gives me a segfault with a preg_split
# 2964    #heyxboxlive Probably shouldn't mention any sh...
# Name: text, dtype: object
# 348      woke up and was having an accident - &quot;It...
# 979      Total cost of the atk for the aggressor: 273,...
# 2030             8oz Golem  But finally got a Wight - 3oz
# 2404               gives me a segfault with a preg_split
# 2964     Probably shouldn't mention any show with Drew...
# Name: text, dtype: object

# %% [markdown]
# 5. find e-mails

# %%
regex = r"([A-Za-z0-9]+)@\S+.com\S+"

df['text'].str.replace(regex, '')
print("tweets:")
display(df['text'][df['text'].str.match(regex)== True].head())
display(df['text'].str.replace(regex, '', regex=True)[df['text'].str.match(regex)== True].head())
# Out:
# tweets:
# Series([], Name: text, dtype: object)
# Series([], Name: text, dtype: object)
